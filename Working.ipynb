# %%
import pandas as pd
import numpy as np

# %%
# Main csv file
data = pd.read_csv('./before_cleaning.csv')

# %%
# Statewise values
data.state.value_counts()
# Out:
# ca    8056
# tx    5265
# ny    4918
# fl    4245
# pa    3218
# il    3123
# oh    2952
# mi    2813
# nc    2195
# nj    2010
# ga    1969
# va    1907
# az    1526
# in    1511
# tn    1497
# ma    1478
# wa    1458
# wi    1409
# md    1406
# mo    1393
# mn    1338
# co    1249
# al    1181
# la    1148
# ky    1115
# sc    1103
# ok    1046
# or     834
# ct     833
# ia     825
# ks     770
# nv     687
# ar     686
# ms     664
# ut     588
# ne     532
# nm     499
# wv     484
# me     358
# id     298
# nh     295
# mt     271
# ri     244
# sd     222
# de     218
# nd     205
# vt     184
# dc     179
# wy     132
# Name: state, dtype: int64

# %% [raw]
# # We are takinng 5 states in consideration
# # States are California, New York, Florida, Texas, Nevada

# %%
# Fetch specific data with state have value as Ca=Califorina
california = (data[data.state=='ca'])
# Reset index from 0.
california = california.reset_index()

# %%
# Drop newly un-necessary created index column
california = california.drop(columns=['index'])
california.head()
# Out:
#    tile_count  solar_system_count  total_panel_area        fips  \
# 0          82                  69       1857.673883  6037504001
# 1         123                 100       2319.961258  6037504002
# 2          85                  72       2655.439639  6037700700
# 3          77                  44       4692.276309  6037700801
# 4          36                  21       1428.185561  6037700802
#
#    average_household_income              county  education_bachelor  \
# 0               88640.33101  Los Angeles County                 380
# 1               99115.35859  Los Angeles County                 524
# 2              414706.23820  Los Angeles County                 726
# 3              107896.20160  Los Angeles County                1223
# 4              123826.46250  Los Angeles County                 905
#
#    education_college  education_doctoral  education_high_school_graduate  ...  \
# 0               1056                  56                             583  ...
# ...

# %%
# # Fetch specific data with state have value as ny=New York
newYork = (data[data.state=='ny'])
# # Reset index from 0.
newYork = newYork.reset_index()
# # Drop newly un-necessary created index column
newYork = newYork.drop(columns=['index'])
newYork.head()
# Out:
#    tile_count  solar_system_count  total_panel_area         fips  \
# 0          10                   8        264.512905  36071014400
# 1           2                   2         66.187708  36071014900
# 2          11                   9        170.548930  36071015004
# 3          15                  14        326.576931  36071015005
# 4           5                   3        161.796515  36071014502
#
#    average_household_income         county  education_bachelor  \
# 0              108954.82200  Orange County                 701
# 1              122821.44240  Orange County                 742
# 2               39521.76422  Orange County                  51
# 3               48647.39583  Orange County                  30
# 4              129044.95600  Orange County                 762
#
#    education_college  education_doctoral  education_high_school_graduate  ...  \
# 0                929                  35                             804  ...
# ...

# %%
# Fetch specific data with state have value as Ca=Califorina
texas = (data[data.state=='tx'])
# Reset index from 0.
texas = texas.reset_index()
# Drop newly un-necessary created index column
texas = texas.drop(columns=['index'])
texas.head()
# Out:
#    tile_count  solar_system_count  total_panel_area         fips  \
# 0           0                   0          0.000000  48113014114
# 1           3                   3        113.126210  48113014121
# 2          19                  15        572.530053  48113014126
# 3           9                   7        124.324405  48113014137
# 4           1                   1         10.748193  48113014138
#
#    average_household_income         county  education_bachelor  \
# 0               38053.77984  Dallas County                 276
# 1               89785.37879  Dallas County                1252
# 2              142366.31580  Dallas County                1669
# 3              137700.13180  Dallas County                1269
# 4              114209.74830  Dallas County                1460
#
#    education_college  education_doctoral  education_high_school_graduate  ...  \
# 0                560                   0                             548  ...
# ...

# %%
# Fetch specific data with state have value as Ca=Califorina
florida = (data[data.state=='fl'])
# Reset index from 0.
florida = florida.reset_index()
# Drop newly un-necessary created index column
florida = florida.drop(columns=['index'])
florida.head()
# Out:
#    tile_count  solar_system_count  total_panel_area         fips  \
# 0           4                   4        118.084786  12031011500
# 1          29                  24        988.661970  12031011901
# 2          33                  30       1064.100798  12031011902
# 3           3                   3         59.724035  12031012200
# 4           3                   3        147.546220  12031012500
#
#    average_household_income        county  education_bachelor  \
# 0               30031.33106  Duval County                 109
# 1               59260.19455  Duval County                 526
# 2               66910.50528  Duval County                 954
# 3               32713.86243  Duval County                 340
# 4               41694.01316  Duval County                 184
#
#    education_college  education_doctoral  education_high_school_graduate  ...  \
# 0                500                   0                            1129  ...
# ...

# %%
# Fetch specific data with state have value as Ca=Califorina
nevada = (data[data.state=='nv'])
# Reset index from 0.
nevada = nevada.reset_index()
# Drop newly un-necessary created index column
nevada = nevada.drop(columns=['index'])
nevada.head()
# Out:
#    tile_count  solar_system_count  total_panel_area         fips  \
# 0           4                   2        125.188428  32001950400
# 1           8                   4        524.854264  32001950500
# 2          10                   5        671.221494  32001950301
# 3           7                   6        195.257864  32001950302
# 4          14                  14        301.641891  32001950600
#
#    average_household_income            county  education_bachelor  \
# 0               43428.45528  Churchill County                  56
# 1               48432.14286  Churchill County                  88
# 2               42443.29004  Churchill County                 181
# 3               51566.11328  Churchill County                 389
# 4               81083.07943  Churchill County                 392
#
#    education_college  education_doctoral  education_high_school_graduate  ...  \
# 0                172                   0                              82  ...
# ...

# %%
# Here are list of columns and data is manipulated in form of list.
columns = list(data.columns)

# %%
# Create empty dataFrame for each 5 states for new data
californiaFinal = pd.DataFrame(columns=columns)
texasFinal = pd.DataFrame(columns=columns)
newYorkFinal = pd.DataFrame(columns=columns)
floridaFinal = pd.DataFrame(columns=columns)
nevadaFinal = pd.DataFrame(columns=columns)

# %%
# Califorrnia shuffled dataframe using random number to not get skewed data.
# Generate random number module
import random
# random.randint(0, 8055)
for x in range(0, 300):
    number = random.randint(0, 8055)
    californiaFinal = californiaFinal.append(california.iloc[number], ignore_index=True)
californiaFinal.head()
# Out:
#   tile_count solar_system_count  total_panel_area        fips  \
# 0          3                  2        222.576918  6073021000
# 1          7                  5        310.533673  6001403000
# 2          0                  0          0.000000  6037930301
# 3          6                  3        127.804947  6037576903
# 4        183                148       3842.270171  6085512035
#
#    average_household_income              county education_bachelor  \
# 0               39216.47203    San Diego County                309
# 1               38592.13857      Alameda County                446
# 2               76920.24793  Los Angeles County                 57
# 3               49618.23856  Los Angeles County                251
# 4              122012.86630  Santa Clara County                965
#
#   education_college education_doctoral education_high_school_graduate  ...  \
# 0               855                 16                            844  ...
# ...

# %%
# New York shuffled dataframe using random number to not get skewed data.
import random
# random.randint(0, 8055)
for x in range(0, 300):
    number = random.randint(0, 4917)
    newYorkFinal = newYorkFinal.append(newYork.iloc[number], ignore_index=True)
newYorkFinal.head()
# Out:
#   tile_count solar_system_count  total_panel_area         fips  \
# 0          0                  0          0.000000  36047010800
# 1          5                  3        309.120387  36091060400
# 2        115                 80       2731.650199  36103158110
# 3          1                  1         67.120232  36015010100
# 4         29                 10       1664.649837  36091062505
#
#    average_household_income           county education_bachelor  \
# 0               47382.33054     Kings County                250
# 1               52847.04082  Saratoga County                160
# 2              110323.63640   Suffolk County                438
# 3               62064.50954   Chemung County                273
# 4              104209.69880  Saratoga County                855
#
#   education_college education_doctoral education_high_school_graduate  ...  \
# 0               279                 22                            743  ...
# ...

# %%
# Texas shuffled dataframe using random number to not get skewed data.
import random
# random.randint(0, 8055)
for x in range(0, 300):
#     Generate random number everytime in for loop
#     Generate random number everytime due to geting not skewed data
    number = random.randint(0, 5265)
#     Getting random rows for not getting random rows
    texasFinal = texasFinal.append(texas.iloc[number], ignore_index=True)
texasFinal.head()
# Out:
#   tile_count solar_system_count  total_panel_area         fips  \
# 0          0                  0          0.000000  48113013625
# 1          0                  0          0.000000  48365950100
# 2          4                  4         84.497342  48167720302
# 3          1                  1         11.911410  48073951000
# 4          5                  5        110.239394  48439104100
#
#    average_household_income            county education_bachelor  \
# 0               43573.50689     Dallas County                369
# 1               68844.43142     Panola County                226
# 2              135933.85460  Galveston County               1559
# 3               51560.70901   Cherokee County                224
# 4               70437.58440    Tarrant County                517
#
#   education_college education_doctoral education_high_school_graduate  ...  \
# 0               360                 56                            501  ...
# ...

# %%
# Florida shuffled dataframe using random number to not get skewed data.
import random
# random.randint(0, 8055)
for x in range(0, 300):
#     Generate random number everytime in for loop
#     Generate random number everytime due to geting not skewed data
    number = random.randint(0, 4244)
#     Getting random rows for not getting random rows
    floridaFinal = floridaFinal.append(florida.iloc[number], ignore_index=True)
floridaFinal.head()
# Out:
#   tile_count solar_system_count  total_panel_area         fips  \
# 0        158                146       4373.898018  12057011506
# 1          1                  1         24.523560  12086000128
# 2          1                  1         22.630896  12057010812
# 3          0                  0          0.000000  12057003400
# 4          0                  0          0.000000  12011060303
#
#    average_household_income               county education_bachelor  \
# 0              111421.09910  Hillsborough County               1990
# 1               66986.38590    Miami-Dade County                421
# 2               32328.09349  Hillsborough County                581
# 3               26465.06986  Hillsborough County                123
# 4               30963.79147       Broward County                133
#
#   education_college education_doctoral education_high_school_graduate  ...  \
# 0              1411                 74                            568  ...
# ...

# %%
# Nevada shuffled dataframe using random number to not get skewed data.
import random
# random.randint(0, 8055)
for x in range(0, 300):
#     Generate random number everytime in for loop
#     Generate random number everytime due to geting not skewed data
    number = random.randint(0, 686)
#     Getting random rows for not getting random rows    
    nevadaFinal = nevadaFinal.append(nevada.iloc[number], ignore_index=True)
nevadaFinal.head()
# Out:
#   tile_count solar_system_count  total_panel_area         fips  \
# 0         35                 26       1848.991209  32003002950
# 1         98                 80       2390.328204  32003003627
# 2        108                 88       2771.018062  32003003006
# 3         61                 56       1375.107736  32003004925
# 4         12                  5        677.444548  32031000101
#
#    average_household_income         county education_bachelor  \
# 0               56154.97630   Clark County                607
# 1               60384.50609   Clark County                366
# 2               56172.08077   Clark County                245
# 3               58402.22584   Clark County                306
# 4               56926.30309  Washoe County                387
#
#   education_college education_doctoral education_high_school_graduate  ...  \
# 0              1086                  0                           1138  ...
# ...

# %%
# Merging all dataframe in finalDataSet
finalDataSet = californiaFinal.append(texasFinal).append(floridaFinal).append(newYorkFinal).append(nevadaFinal)

# %%
finalDataSet = finalDataSet.reset_index()
finalDataSet = finalDataSet.drop(columns=['index'])

# %%
finalDataSet.head()
# Out:
#   tile_count solar_system_count  total_panel_area        fips  \
# 0          3                  2        222.576918  6073021000
# 1          7                  5        310.533673  6001403000
# 2          0                  0          0.000000  6037930301
# 3          6                  3        127.804947  6037576903
# 4        183                148       3842.270171  6085512035
#
#    average_household_income              county education_bachelor  \
# 0               39216.47203    San Diego County                309
# 1               38592.13857      Alameda County                446
# 2               76920.24793  Los Angeles County                 57
# 3               49618.23856  Los Angeles County                251
# 4              122012.86630  Santa Clara County                965
#
#   education_college education_doctoral education_high_school_graduate  ...  \
# 0               855                 16                            844  ...
# ...

# %%
# Equal distribution is created.
finalDataSet.state.value_counts()
# Out:
# ny    300
# fl    300
# tx    300
# nv    300
# ca    300
# Name: state, dtype: int64

# %%
gini = finalDataSet.gini_index
electricityPrice = finalDataSet.electricity_price_overall

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# fig, ax = plt.subplots()
sns.jointplot(gini,electricityPrice, kind='hex')

# %%
finalDataSet.total_panel_area_residential.sum()
# Out:
# 1325988.2999999998

# %%
finalDataSet.total_panel_area_nonresidential.sum()
# Out:
# 1990857.9

# %%
panelAreasValues = [finalDataSet.total_panel_area_residential.sum(), finalDataSet.total_panel_area_nonresidential.sum()]
panelAreasKeys = ['Total panel area residential', 'Total panel area non-residential']

# %%
fig3, ax3 = plt.subplots()
ax3 = sns.barplot(panelAreasKeys, panelAreasValues, palette='Blues_d')
ax3.set_xlabel('Category', fontsize = 25)
ax3.set_ylabel('Total solar panel area', fontsize=25)
ax3.tick_params(labelsize=18)
fig3.set_size_inches(11.7, 8.27)
ax3.set_title('Solar panel areas in residential and non-residential', fontsize=25)
plt.show()

# %%
frostDaysMean = int(finalDataSet.frost_days.mean())

# %%
finalDataSet.frost_days = (finalDataSet.frost_days.fillna(frostDaysMean))

# %%
fig2, ax2 = plt.subplots()
ax2 = sns.scatterplot(finalDataSet.frost_days, finalDataSet.solar_system_count, marker='+')
ax2.set_xlabel('Frost days', fontsize=20)
ax2.set_ylabel('Total solar systems', fontsize=20)
fig2.set_size_inches(11.7, 8.27)
ax2.tick_params(labelsize=18)
ax2.set_title('Frost days to total solar system', fontsize=25)
plt.show()

# %%
finalDataSet.daily_solar_radiation = finalDataSet.daily_solar_radiation.fillna(finalDataSet.daily_solar_radiation.mean())

# %%
# Top 5 county with maximum number of solar systems
numberOfSolarSytemsCounty = dict()
countyDict = (finalDataSet.county.value_counts()).to_dict()
countyList = list(countyDict.keys())
# for x in countyList:
#     counter = 0
#     if finalDataSet.county == x:

# %%
for data1 in countyList:
    counter = 0
    for idx, row in finalDataSet.iterrows():
        if row.county == data1:
            counter = counter + row.solar_system_count
    numberOfSolarSytemsCounty.update({data1:counter})

# %%
# lambda is function implementation.
sortedCountyData = sorted(numberOfSolarSytemsCounty.items(), key=lambda x: x[1], reverse=True)
# Geetting first 5 data with maximum number of solar systems
finalCountyData = sortedCountyData[0:5]

# %%
countyName = []
countyValues = []

# %%
for x in range(0, 5):
    countyName.append(finalCountyData[x][0])
    countyValues.append(finalCountyData[x][1])

# %%
fig1, ax1 = plt.subplots()
ax1 = sns.lineplot(countyName, countyValues)
ax1.set_xlabel('County names', fontsize = 20)
ax1.set_ylabel('Number of solar systems', fontsize=20)
fig1.set_size_inches(11.7, 8.27)
ax1.tick_params(labelsize=14)
ax1.set_title('Top 5 county with highest number of solar systems', fontsize=25)
plt.show()
# ax.set(ylim=(1344000, 1635000))

# %%
finalDataSet.average_household_income.isna().sum()
finalDataSet.average_household_income = finalDataSet.average_household_income.fillna(finalDataSet.average_household_income.mean())
averageHouseholdIncome = finalDataSet.average_household_income
stateNames = ['California', 'Texas', 'Florida', 'New York', 'Nevada']
fig5, ax5 = plt.subplots()
ax5 = sns.boxplot(x=finalDataSet['state'], y=finalDataSet['average_household_income'])
ax5.set_xlabel('States', fontsize = 20)
ax5.set_ylabel('Average household income', fontsize = 20)
fig5.set_size_inches(11.7, 8.27)
ax5.tick_params(labelsize=14)
ax5.set_title('Average household income of 5 states', fontsize=25)
plt.show()

# %%
finalDataSet.gini_index = finalDataSet.gini_index.fillna(finalDataSet.gini_index.mean())

# %%
giniIndex = finalDataSet.gini_index

# %%
fig6, ax6 = plt.subplots()
ax6 = sns.scatterplot(finalDataSet.education_population, finalDataSet.solar_system_count)
ax6.set_xlabel('Educated population', fontsize=20)
ax6.set_ylabel('Total solar systems', fontsize=20)
fig6.set_size_inches(11.7, 8.27)
ax6.tick_params(labelsize=18)
ax6.set_title('Educated population to number total solar systems', fontsize=25)
plt.show()
# ax2.set_title('Frost days to total solar system', fontsize=25)

# %%
summaryStats = finalDataSet[['state', 'solar_system_count', 'education_population', 'county', 'gini_index', 'electricity_price_overall', 'solar_system_count', 'frost_days', 'total_panel_area_residential', 'total_panel_area_nonresidential', 'average_household_income']]
summaryStats.describe(include='all')
# Out:
#        state  solar_system_count  education_population        county  \
# count   1500              1500.0                1500.0          1500
# unique     5               190.0                1204.0           198
# top       ny                 0.0                   0.0  Clark County
# freq     300               218.0                  22.0           213
# mean     NaN                 NaN                   NaN           NaN
# std      NaN                 NaN                   NaN           NaN
# min      NaN                 NaN                   NaN           NaN
# 25%      NaN                 NaN                   NaN           NaN
# 50%      NaN                 NaN                   NaN           NaN
# 75%      NaN                 NaN                   NaN           NaN
# max      NaN                 NaN                   NaN           NaN
#
#          gini_index  electricity_price_overall  solar_system_count  \
# count   1500.000000                1500.000000              1500.0
# ...

# %%
summaryStats1 = finalDataSet[['state', 'solar_system_count', 'education_population', 'county']]

# %%
summaryStats1.describe()
# Out:
#        state  solar_system_count  education_population        county
# count   1500                1500                  1500          1500
# unique     5                 190                  1204           198
# top       ny                   0                     0  Clark County
# freq     300                 218                    22           213

# %% [markdown]
# # Data cleaning

# %%
nuOfColumns = list(finalDataSet.columns)

# %%
print("Actual Dataset has {} number of columns.".format(len(nuOfColumns)))
# Out:
# Actual Dataset has 168 number of columns.

# %%
final = finalDataSet[['state', 'solar_system_count', 'education_population', 'county', 'gini_index', 'electricity_price_overall', 'solar_system_count', 'frost_days', 'total_panel_area_residential', 'total_panel_area_nonresidential', 'average_household_income']]
print('We dropped {} columns and used {} columns.'.format(157, len(list(final.columns))))
# Out:
# We dropped 157 columns and used 11 columns.

# %%
print('Data set has {} null values in gini_index feature.'.format(finalDataSet.gini_index.isna().sum()))
print('Data set has {} null values in frost_days feature.'.format(finalDataSet.frost_days.isna().sum()))
print('Data set has {} null values in average_household_income feature.'.format(finalDataSet.average_household_income.isna().sum()))
# Out:
# Data set has 27 null values in gini_index feature.
# Data set has 108 null values in frost_days feature.
# Data set has 29 null values in average_household_income feature.

# %%
# After data cleaning we fill all above null values with mean...
finalDataSet.frost_days = finalDataSet.frost_days.fillna(int(finalDataSet.frost_days.mean()))
finalDataSet.average_household_income = finalDataSet.average_household_income.fillna(int(finalDataSet.average_household_income.mean()))
finalDataSet.gini_index = finalDataSet.gini_index.fillna(int(finalDataSet.gini_index.mean()))

# %%
print('After data cleaning data set has {} null values in gini_index feature.'.format(finalDataSet.gini_index.isna().sum()))
print('After data cleaningData set has {} null values in frost_days feature.'.format(finalDataSet.frost_days.isna().sum()))
print('After data cleaning data set has {} null values in average_household_income feature.'.format(finalDataSet.average_household_income.isna().sum()))
# Out:
# After data cleaning data set has 0 null values in gini_index feature.
# After data cleaningData set has 0 null values in frost_days feature.
# After data cleaning data set has 0 null values in average_household_income feature.
